# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread("/content/drive/MyDrive/123.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=826x826>

# %%
blur = cv2.GaussianBlur(image, ksize=(3,3), sigmaX=0)
ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)
edged = cv2.Canny(blur, 10, 250)
cv2_imshow(edged)
# Out:
# <PIL.Image.Image image mode=L size=826x826>
